# %% [markdown]
# ## ICE-9 Image Restoration and Reconstruction

# %% [markdown]
# # Use this image : https://en.wikipedia.org/wiki/Lenna#/media/File:Lenna_(test_image).png
#
# ### Salt and pepper noise
#
#
# (Tutorial)
# - Salt-and-pepper noise can only be added in a grayscale image. So, convert an image to grayscale after reading it
# - Randomly pick the number of pixels to which noise is added (number_of_pixels)
# - Randomly pick some pixels in the image to which noise will be added. It can be done by randomly picking x and y coordinate
# - Note the random values generated must be within the range of the image dimensions. The x and y coordinates must be within the range of the image size
# Random numbers can be generated using random number generator functions like random.randint used in the code
# - Color some randomly picked pixels as black setting their value to 0
# - Color some randomly picked pixels as white setting their value to 255
# Save the value of the image

# %%
# !apt install subversion
# !svn checkout https://github.com/chakravarthulaharsha/feature_engineering
import numpy as np
import random
import cv2 as c
from google.colab.patches import cv2_imshow as show
def add_noise(img):
    # Getting the dimensions of the image
    row , col = img.shape
    # Randomly pick some pixels in the
    # image for coloring them white
    # Pick a random number between 300 and 10000
    number_of_pixels = random.randint(300, 10000)
    for i in range(number_of_pixels):
       
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
         
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
         
        # Color that pixel to white
        img[y_coord][x_coord] = 255
         
    # Randomly pick some pixels in
    # the image for coloring them black
    # Pick a random number between 300 and 10000
    number_of_pixels = random.randint(300 , 10000)
    for i in range(number_of_pixels):
       
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
         
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
         
        # Color that pixel to black
        img[y_coord][x_coord] = 0
         
    return img

# salt-and-pepper noise can
# be applied only to grayscale images
# Reading the color image in grayscale image
img = c.imread('/content/feature_engineering/trunk/images/Lenna_(test_image).png',
                 c.IMREAD_GRAYSCALE)

print ("\n \n Original Image : \n \n ")

show(img)

img2 = add_noise(img)

print ("\n \n Image with salt and pepper noise : \n \n ")

show(img2)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# subversion is already the newest version (1.9.7-4ubuntu1.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Checked out revision 14.
#
#
#  Original Image :
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA937261C50>
#
#  Image with salt and pepper noise :
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA937267D90>

# %% [markdown]
# # Question 1
# ## Explain briefly why is noise found in an image . What are the ways to reduce it ?

# %% [markdown]
# ### ANSWER HERE
#
# Noice are found in the picture in many forms such as while transferring the image from one device to other, or due to the thermal distrubances while clicking the pictures and due to camera quality of capturing the image and the light scattering while taking the image are the reasons for Noice in the picture. There are various filters that allows to reduce the noice from a picture. Picture is a set of pixels which can be converted into a numpy array so the filters can find the patterns of the noice and reduce those noice.

# %% [markdown]
# ## Task 1
#
# ### Use the salt pepper noise image above and reduce noise in it .
#
# - Use Median Filter
# - Before starting print the noisy image
# - Reduce noise and comment your code appropriately
# - Print the image obtained after you apply filter and reducing noise .

# %%
# Code here 
median = c.medianBlur(img2, 5)
#side by side comparison
print ("Noice Image / Median Filtered Image \n ")
show(np.concatenate((img2, median), axis=1))
c.waitKey(0)
c.destroyAllWindows
# Out:
# Noice Image / Median Filtered Image
# <PIL.Image.Image image mode=L size=1024x512 at 0x7FA9371FE1D0>
# <function destroyAllWindows>

# %% [markdown]
# # Question 2
#
# ## In task 1 why is Median filter chosen . What is the use of median filter here ?

# %% [markdown]
# Noice of the image can be removed and the edges are preserved using the median filter. **The salt and pepper noise that was added to the noise in the image above can be reduced with the median filter, which is the optimum filter for this purpose.**

# %% [markdown]
# ## Task 2.
#
# ### Use the image  given above (lenna png) and add Poisson Noise in it
#
# **Hint : Use OpenCV-Python**

# %%
# Adding poisson noise
img = c.imread('/content/feature_engineering/trunk/images/Lenna_(test_image).png')
r,co,ch = img.shape
p_noise  = np.random.poisson(img / (r/2) * (10 ** 0.9)) / (10 ** 0.9) * (r/2)
print("Poisson Noise Image is : \n")
show(p_noise)
# Out:
# Poisson Noise Image is :
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA94468FB90>
